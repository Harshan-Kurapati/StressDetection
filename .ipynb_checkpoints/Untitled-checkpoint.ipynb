# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("stress_detection.csv")

# %%
df.columns
# Out:
# Index(['participant_id', 'day', 'PSS_score', 'Openness', 'Conscientiousness',
#        'Extraversion', 'Agreeableness', 'Neuroticism', 'sleep_time',
#        'wake_time', 'sleep_duration', 'PSQI_score', 'call_duration',
#        'num_calls', 'num_sms', 'screen_on_time', 'skin_conductance',
#        'accelerometer', 'mobility_radius', 'mobility_distance'],
#       dtype='object')

# %% [markdown]
# # check missing values

# %%
df.isnull().sum()
# Out:
# participant_id       0
# day                  0
# PSS_score            0
# Openness             0
# Conscientiousness    0
# Extraversion         0
# Agreeableness        0
# Neuroticism          0
# sleep_time           0
# wake_time            0
# sleep_duration       0
# PSQI_score           0
# call_duration        0
# num_calls            0
# num_sms              0
# screen_on_time       0
# skin_conductance     0
# accelerometer        0
# mobility_radius      0
# mobility_distance    0
# dtype: int64

# %%
sleep_duration = df.groupby("participant_id")["sleep_duration"].mean().reset_index()

# %%
students
# Out:
#     participant_id  sleep_duration
# 0                1        7.540548
# 1                2        7.384599
# 2                3        7.466395
# 3                4        7.464438
# 4                5        7.195167
# ..             ...             ...
# 95              96        7.543881
# 96              97        7.792883
# 97              98        7.431049
# 98              99        7.504610
# 99             100        7.509815
#
# [100 rows x 2 columns]

# %%
plt.boxplot(students[["sleep_duration"]])

# %%
uq
# Out:
# 7.587597201075001

# %%
averaged_df = df.set_index('participant_id').mean(level='participant_id').reset_index()
# Out:
# /var/folders/4w/x20vvvw12qv75l7cr78cr3f00000gn/T/ipykernel_1772/1305338201.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.median(level=1) should use df.groupby(level=1).median().
#   averaged_df = df.set_index('participant_id').mean(level='participant_id').reset_index()

# %%
averaged_df
# Out:
#     participant_id   day  PSS_score  Openness  Conscientiousness  \
# 0                1  15.5  24.066667  2.969871           2.936993
# 1                2  15.5  26.100000  2.827940           3.001828
# 2                3  15.5  24.800000  3.235542           3.138758
# 3                4  15.5  26.233333  3.077437           3.082911
# 4                5  15.5  28.033333  3.191693           2.836798
# ..             ...   ...        ...       ...                ...
# 95              96  15.5  24.533333  3.419046           2.507409
# 96              97  15.5  23.200000  3.195854           3.104051
# 97              98  15.5  22.733333  2.913129           2.980791
# 98              99  15.5  26.166667  2.844128           3.159861
# 99             100  15.5  26.766667  3.112094           3.086468
#
#     Extraversion  Agreeableness  Neuroticism  sleep_time  wake_time  \
# 0       3.122456       2.854310     2.926617    7.269013   6.956866
# 1       3.008937       3.081391     3.086240    6.742281   6.810500
# 2       3.522825       3.219264     3.155350    6.839895   7.064615
# 3       3.278380       3.341137     3.381396    6.756088   6.877770
# 4       3.235874       3.630611     2.704031    7.022556   7.027996
# ..           ...            ...          ...         ...        ...
# 95      3.197089       3.253556     3.283526    7.119393   7.226321
# 96      3.094719       2.889947     2.647102    6.744311   6.631345
# 97      3.250434       2.914711     3.226234    6.821178   6.538818
# 98      3.129125       3.033630     3.138698    7.170891   7.242148
# 99      2.877808       3.203288     2.851673    6.868162   7.024180
#
#     sleep_duration  PSQI_score  call_duration  num_calls    num_sms  \
# 0         7.540548    2.633333      19.760314   8.500000  21.933333
# 1         7.384599    2.433333      29.172357  11.100000  19.900000
# 2         7.466395    2.500000      28.073702   9.433333  25.966667
# 3         7.464438    2.566667      23.602981  10.800000  25.500000
# 4         7.195167    2.333333      28.302501   8.333333  26.366667
# ..             ...         ...            ...        ...        ...
# 95        7.543881    3.066667      31.762000   9.133333  27.133333
# 96        7.792883    2.366667      31.352529  11.400000  27.633333
# 97        7.431049    2.333333      29.036246  11.100000  25.566667
# 98        7.504610    2.366667      32.217069  10.066667  21.066667
# 99        7.509815    3.300000      31.523700   9.300000  24.733333
#
#     screen_on_time  skin_conductance  accelerometer  mobility_radius  \
# 0         6.485120          2.695539       1.158174         0.671508
# 1         6.131251          2.327401       1.439580         0.862241
# 2         6.958746          2.748044       1.411158         0.753431
# 3         6.362512          2.675821       1.317718         0.878416
# 4         6.160440          3.035382       1.277119         0.748953
# ..             ...               ...            ...              ...
# 95        5.979690          2.646084       1.195713         0.618875
# 96        7.506417          2.481193       1.355601         0.721882
# 97        5.967230          2.663355       1.509681         0.957817
# 98        7.795772          2.812793       1.458653         0.750879
# 99        6.640219          2.769872       1.476179         0.920366
#
#     mobility_distance
# 0            2.549460
# 1            2.683636
# 2            2.899066
# 3            2.970955
# 4            3.015329
# ..                ...
# 95           2.825785
# 96           3.134840
# 97           2.774358
# 98           2.316705
# 99           2.738737
#
# [100 rows x 20 columns]

# %%
plt.boxplot(averaged_df["sleep_duration"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x143fc05d0>,
#   <matplotlib.lines.Line2D at 0x143fc1190>],
#  'caps': [<matplotlib.lines.Line2D at 0x143fc16d0>,
#   <matplotlib.lines.Line2D at 0x143fc27d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x143fb7890>],
#  'medians': [<matplotlib.lines.Line2D at 0x143fc3290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x143fc1150>],
#  'means': []}

# %%
averaged_df["sleep_duration"].quantile(0.75)
# Out:
# 7.587597201075001

# %%
averaged_df.columns
# Out:
# Index(['participant_id', 'day', 'PSS_score', 'Openness', 'Conscientiousness',
#        'Extraversion', 'Agreeableness', 'Neuroticism', 'sleep_time',
#        'wake_time', 'sleep_duration', 'PSQI_score', 'call_duration',
#        'num_calls', 'num_sms', 'screen_on_time', 'skin_conductance',
#        'accelerometer', 'mobility_radius', 'mobility_distance'],
#       dtype='object')

# %%
plt.scatter(averaged_df["sleep_duration"], averaged_df["screen_on_time"])

# %%
plt.scatter(averaged_df["num_sms"], averaged_df["screen_on_time"])

# %% [markdown]
# # Descriptive Statistics

# %%
summarised_stats = averaged_df.describe()
summarised_stats.loc["Median"] = averaged_df.median()

# %%
summarised_stats
# Out:
#         participant_id    day   PSS_score    Openness  Conscientiousness  \
# count       100.000000  100.0  100.000000  100.000000         100.000000
# mean         50.500000   15.5   24.701000    3.020663           3.007883
# std          29.011492    0.0    1.504743    0.227403           0.228117
# min           1.000000   15.5   21.366667    2.324633           2.507409
# 25%          25.750000   15.5   23.591667    2.863373           2.879827
# 50%          50.500000   15.5   24.533333    3.001011           2.964313
# 75%          75.250000   15.5   25.775000    3.156850           3.146568
# max         100.000000   15.5   28.300000    3.623140           3.601729
# Median       50.500000   15.5   24.533333    3.001011           2.964313
#
#         Extraversion  Agreeableness  Neuroticism  sleep_time   wake_time  \
# count     100.000000     100.000000   100.000000  100.000000  100.000000
# mean        3.002101       3.047659     2.963589    7.002145    6.990567
# std         0.209116       0.197830     0.174587    0.223740    0.217487
# min         2.541234       2.553244     2.552902    6.473369    6.410473
# 25%         2.869102       2.908417     2.834348    6.825933    6.854937
# 50%         3.003397       3.037063     2.993713    6.993814    7.024273
# 75%         3.130972       3.187343     3.081540    7.163977    7.147114
# max         3.522825       3.630611     3.381396    7.449107    7.454403
# Median      3.003397       3.037063     2.993713    6.993814    7.024273
#
#         sleep_duration  PSQI_score  call_duration   num_calls     num_sms  \
# count       100.000000  100.000000     100.000000  100.000000  100.000000
# mean          7.477953    2.490333      29.717149    9.362000   24.472333
# std           0.151785    0.213689       3.288896    1.034978    2.547784
# min           7.076463    2.066667      19.760314    6.866667   16.800000
# 25%           7.387071    2.333333      27.784439    8.633333   23.425000
# 50%           7.469178    2.483333      29.999526    9.416667   24.666667
# 75%           7.587597    2.608333      31.805816   10.066667   25.991667
# max           7.868934    3.300000      37.639565   12.500000   29.866667
# Median        7.469178    2.483333      29.999526    9.416667   24.666667
#
#         screen_on_time  skin_conductance  accelerometer  mobility_radius  \
# count       100.000000        100.000000     100.000000       100.000000
# mean          6.624776          2.762022       1.317038         0.803164
# std           0.530568          0.226533       0.122943         0.078810
# min           5.174174          2.203404       1.066515         0.595461
# 25%           6.259102          2.640823       1.218184         0.743516
# 50%           6.593868          2.758899       1.315398         0.804774
# 75%           7.021334          2.908969       1.397322         0.859561
# max           7.835734          3.311819       1.627767         0.989175
# Median        6.593868          2.758899       1.315398         0.804774
#
#         mobility_distance
# count          100.000000
# mean             2.801677
# std              0.254303
# min              2.224545
# 25%              2.681601
# 50%              2.799814
# 75%              2.973052
# max              3.429278
# Median           2.799814

# %% [markdown]
# #  Correlations and Relationships

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x= "screen_on_time", y = "sleep_duration", data = averaged_df)
plt.title("Does screen on time impacts sleep duration?")
plt.show()

print(f"The correlation between Screen on time and Sleep Duration is : {averaged_df['screen_on_time'].corr(averaged_df['sleep_duration'])}")
# Out:
# The correlation between Screen on time and Sleep Duration is : -0.024988575778862928
